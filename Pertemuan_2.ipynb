# %% [markdown]
# <a href="https://colab.research.google.com/github/ariwramadhan90-oss/pertemuan_2/blob/main/Pertemuan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Jawaban Latihan 1

tegangan_panel = 18
arus_panel = 6
jenis_sel = "monocrystaline"

print(tegangan_panel)
print(arus_panel)
print(jenis_sel)
# Out:
# 18
# 6
# monocrystaline

# %%
#Jawaban latihan 2

jumlah_panel = 240         #int
tegangan_panel = 48.5      #float
panel_aktif = True         #bool
nama_komponen = "Resistor" #str

print(jumlah_panel), type(jumlah_panel)
print(tegangan_panel), type(tegangan_panel)
print(panel_aktif), type(panel_aktif)
print(nama_komponen), type(nama_komponen)
# Out:
# 240
# 48.5
# True
# Resistor
# (None, str)

# %%
#Jawaban latihan 3

nama_unit = "PLTS Nukan"
jumlah_panel = 240
tegangan_keluar = 48.5
sedang_beroperasi = True

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluar, type(tegangan_keluar))
print(sedang_beroperasi, type(sedang_beroperasi))
# Out:
# PLTS Nukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
# Jawaban Latihan 4

tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

print("Pembacaan pertama :", tegangan_harian[0])
print("Pembacaan terakhir", tegangan_harian[-1])

tegangan_harian.append(222.0)

print("Jumlah total data :", len (tegangan_harian))
# Out:
# Pembacaan pertama : 217.5
# Pembacaan terakhir 216.9
# Jumlah total data : 7

# %%
# Jawaban Latihan 5

motor = {
    "nama": "motor induksi",
    "daya_kw": 5.5,
    "tegangan_V": 380,
    "rpm0": 1450
}

print("nama motor:", motor["nama"])

motor["rpm"] = 1500

print(motor)
# Out:
# nama motor: motor induksi
# {'nama': 'motor induksi', 'daya_kw': 5.5, 'tegangan_V': 380, 'rpm0': 1450, 'rpm': 1500}

# %%
# Jawaban Latihan 6

pembangkit = [
    {"nama": "unit-1", "kapasitas_mw": 100, "status": "operasi"},
    {"nama": "unit-2", "kapasitas_mw": 150, "status": "operasi"},
    {"nama": "unit-3", "kapasitas_mw": 80, "status": "pemeliharaan"},
]

print("nama unit kedua:", pembangkit[1]["nama"])

pembangkit.append({
    "nama": "unit-4",
    "kapasitas_mw": 200,
    "status": "operasi"
})

print(pembangkit)
# Out:
# nama unit kedua: unit-2
# [{'nama': 'unit-1', 'kapasitas_mw': 100, 'status': 'operasi'}, {'nama': 'unit-2', 'kapasitas_mw': 150, 'status': 'operasi'}, {'nama': 'unit-3', 'kapasitas_mw': 80, 'status': 'pemeliharaan'}, {'nama': 'unit-4', 'kapasitas_mw': 200, 'status': 'operasi'}]
